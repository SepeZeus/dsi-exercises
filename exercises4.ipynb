# %% [markdown]
# # Introduction to Data Science 2026
#
# # Week 4

# %% [markdown]
# In this week's exercise, we look at prompting and zero- and few-shot task settings. Below is a text generation example from https://github.com/TurkuNLP/intro-to-nlp/blob/master/text_generation_pipeline_example.ipynb demonstrating how to load a text generation pipeline with a pre-trained model and generate text with a given prompt. Your task is to load a similar pre-trained generative model and assess whether the model succeeds at a set of tasks in zero-shot, one-shot, and two-shot settings.
#
# **Note: Downloading and running the pre-trained model locally may take some time. Alternatively, you can open and run this notebook on [Google Colab](https://colab.research.google.com/), as assumed in the following example.**

# %% [markdown]
# ## Text generation example
#
# This is a brief example of how to run text generation with a causal language model and `pipeline`.
#
# Install [transformers](https://huggingface.co/docs/transformers/index) python package. This will be used to load the model and tokenizer and to run generation.

# %%
# !pip install --quiet transformers

# %% [markdown]
# Import the `AutoTokenizer`, `AutoModelForCausalLM`, and `pipeline` classes. The first two support loading tokenizers and generative models from the [Hugging Face repository](https://huggingface.co/models), and the last wraps a tokenizer and a model for convenience.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# %% [markdown]
# Load a generative model and its tokenizer. You can substitute any other generative model name here (e.g. [other TurkuNLP GPT-3 models](https://huggingface.co/models?sort=downloads&search=turkunlp%2Fgpt3)), but note that Colab may have issues running larger models.

# %%
MODEL_NAME = 'TurkuNLP/gpt3-finnish-large'

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME)
# Out:
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]

# %% [markdown]
# Instantiate a text generation pipeline using the tokenizer and model.

# %%
pipe = pipeline(
    'text-generation',
    model=model,
    tokenizer=tokenizer,
    device=model.device
)

# %% [markdown]
# We can now call the pipeline with a text prompt; it will take care of tokenizing, encoding, generation, and decoding:

# %%
output = pipe('Terve, miten menee?', max_new_tokens=25)

print(output)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=25) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ...

# %% [markdown]
# Just print the text

# %%
print(output[0]['generated_text'])
# Out:
# Terve, miten menee?”, kysyy isä. ”Hyvin, kiitos.”
# ”Eipä siinä mitään, jatka vain matkaasi”, isä sanoo ja

# %% [markdown]
# We can also call the pipeline with any arguments that the model `generate` function supports. For details on text generation using `transformers`, see e.g. [this tutorial](https://huggingface.co/blog/how-to-generate).
#
# Example with sampling and a high `temperature` parameter to generate more chaotic output:

# %%
output = pipe(
    'Terve, miten menee?',
    do_sample=True,
    temperature=10.0,
    max_new_tokens=25
)

print(output[0]['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'do_sample', 'max_new_tokens', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=25) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Terve, miten menee? Mulla sama täällä , tänään aamulla kävin labrakokeita tekemässä sairaalassa verikoekissalla...sedät antoi ihan rauhassa mulle istua vaan labr

# %% [markdown]
# ## Exercise 1
#
# Your task is to assess whether a generative model succeeds in the following tasks in zero-shot, one-shot, and two-shot settings:
#
# - binary sentiment classification (positive / negative)
#
# - person name recognition
#
# - two-digit addition (e.g. 11 + 22 = 33)
#
# For example, for assessing whether a generative model can name capital cities, we could use the following prompts:
#
# - zero-shot:
# 	>"""\
# 	>Identify the capital cities of countries.
# 	>
# 	>Question: What is the capital of Finland?\
# 	>Answer:\
# 	>"""
# - one-shot:
# 	>"""\
# 	>Identify the capital cities of countries.
# 	>
# 	>Question: What is the capital of Sweden?\
# 	>Answer: Stockholm
# 	>
# 	>Question: What is the capital of Finland?\
# 	>Answer:\
# 	>"""
# - two-shot:
# 	>"""\
# 	>Identify the capital cities of countries.
# 	>
# 	>Question: What is the capital of Sweden?\
# 	>Answer: Stockholm
# 	>
# 	>Question: What is the capital of Denmark?\
# 	>Answer: Copenhagen
# 	>
# 	>Question: What is the capital of Finland?\
# 	>Answer:\
# 	>"""
#
# You can do the tasks either in English or Finnish and use a generative model of your choice from the Hugging Face models repository, for example the following models:
#
# - English: `gpt2-large`
# - Finnish: `TurkuNLP/gpt3-finnish-large`
#
# You can either come up with your own instructions for the tasks or use the following:
#
# - English:
# 	- binary sentiment classification: "Do the following texts express a positive or negative sentiment?"
# 	- person name recognition: "List the person names occurring in the following texts."
# 	- two-digit addition: "This is a first grade math exam."
# - Finnish:
# 	- binary sentiment classification: "Ilmaisevatko seuraavat tekstit positiivista vai negatiivista tunnetta?"
# 	- person name recognition: "Listaa seuraavissa teksteissä mainitut henkilönnimet."
# 	- two-digit addition: "Tämä on ensimmäisen luokan matematiikan koe."
#
# Come up with at least two test cases for each of the three tasks, and come up with your own one- and two-shot examples.

# %%
# Out:
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# There are more than 100 pearl beetles under the curfews!
# This will be an update for the past year! We've had a great time, and we've learned so much here in Finland. We'll be

# %% [markdown]
# ### Sentiment analysis
#
# When running with llama-cpp and Gemma 4 31b thinking model with the settings and system prompt:
# ```
# --parallel 1 --temp 1.0 --top-p 0.95 --top-k 20 --min-p 0.0 -ngl 99 --no-mmproj --reasoning-preserve -sys "You are a sentiment analyzer. Do not provide disclaimers about who you are and what your role is."
# ```
#
# For prompts:
#
# **Zero-shot:**
#
# Your task is to identify the sentiment of the following text, the only valid answers you can give are: positive, negative or neutral\n here is the text to analyze: <image of greater Finland with all of the extra land>To anyone wondering how this would solve the Israeli-Palestine conflict: a large Finland would literally solve every single one of the world’s problems, because it would be so beautiful and great. Israel and Palestine would both be so impressed about the big Finland, that they would stop fighting each other. They would be so busy admiring the beautiful large Finland, that they would forget to fight each other, and live happily and peacefully ever after.  Or at least it would probably work that way. In theory. I think we should definitely at least test this solution and give it a try.
#
# **One-shot**
#
# You are a sentiment analyzer.\nYour task is to identify the sentiment of the following text, the only valid answers you can give are: positive, negative or neutral\n here is an example:\nThe given text: The Finno-Korean Hyperwar, also known as the Hwan-Suomi Hyperwar, was an ancient war between the two most powerful empires in the world at the time. The Proto-Finnic Holy Roman Khaganate faced off against the Hwan Empire.\nSentiment:Neutral\n Here is the text to analyze: <image of greater Finland with all of the extra land>To anyone wondering how this would solve the Israeli-Palestine conflict: a large Finland would literally solve every single one of the world’s problems, because it would be so beautiful and great. Israel and Palestine would both be so impressed about the big Finland, that they would stop fighting each other. They would be so busy admiring the beautiful large Finland, that they would forget to fight each other, and live happily and peacefully ever after.  Or at least it would probably work that way. In theory. I think we should definitely at least test this solution and give it a try.
#
# **Two-shot**
#
# You are a sentiment analyzer.\nYour task is to identify the sentiment of the following text, the only valid answers you can give are: positive, negative or neutral\n here are two examples:\nThe given text: The Finno-Korean Hyperwar, also known as the Hwan-Suomi Hyperwar, was an ancient war between the two most powerful empires in the world at the time. The Proto-Finnic Holy Roman Khaganate faced off against the Hwan Empire.\nSentiment:Neutral\n Example 2: \nThe given text: <image of greater Finland with all of the extra land>To anyone wondering how this would solve the Israeli-Palestine conflict: a large Finland would literally solve every single one of the world’s problems, because it would be so beautiful and great. Israel and Palestine would both be so impressed about the big Finland, that they would stop fighting each other. They would be so busy admiring the beautiful large Finland, that they would forget to fight each other, and live happily and peacefully ever after.  Or at least it would probably work that way. In theory. I think we should definitely at least test this solution and give it a try.\nSentiment:positive. Here is the text for you to analyze:\nThe given text: Carpet beetles are evil!
#
#
# It gets the answers correctly for zero-shot, one-shot, and two-shot (technically succeeding in zero-shot makes one and two shot a bit redundant):
#
# **zero-shot:**
# ```
# [Start thinking]
#
# *   Role: Sentiment analyzer.
#     *   Constraint: No disclaimers about identity or role.
#     *   Input: A text describing a hypothetical "Greater Finland" solving the Israeli-Palestine conflict through its beauty and greatness.
#     *   Valid Outputs: positive, negative, or neutral.
#
#     *   Keywords: "solve every single one of the world’s problems", "beautiful and great", "impressed", "stop fighting", "admiring", "live happily and peacefully", "definitely at least test this solution".
#     *   Tone: Sarcastic/Humorous/Optimistic (hyperbolic).
#     *   Overall Sentiment: The speaker is expressing a very high opinion of "Greater Finland" (even if it's a joke) and suggests it would lead to world peace. The language is overwhelmingly positive.
#
#     *   The sentiment is positive.
# [End thinking]
#
# positive
# ```
#
# one-shot:
#
# ```
# [Start thinking]
#
# *   Role: Sentiment analyzer.
#     *   Constraint: No disclaimers.
#     *   Task: Identify sentiment (positive, negative, or neutral).
#     *   Input: A text describing a hypothetical "Greater Finland" solving the Israeli-Palestine conflict because it is "beautiful and great."
#
#     *   Keywords/Phrases: "solve every single one of the world's problems", "so beautiful and great", "impressed", "stop fighting", "admiring", "live happily and peacefully ever after", "definitely... give it a try".
#     *   Tone: Satirical/Absurdist, but the *expressed* sentiment towards the subject (Greater Finland) is overwhelmingly positive.
#     *   Content: The author is praising "big Finland" as a solution to global conflict.
#
#     *   The overall tone is positive/enthusiastic (even if meant as a joke).
# [End thinking]
#
# Positive
#
# ```
#
# two-shot:
# [Start thinking]
#
# *   Role: Sentiment analyzer.
#     *   Constraint: No disclaimers.
#     *   Valid answers: "positive", "negative", "neutral".
#     *   Input text: "carpet beetles are evil!"
#
#     *   Text: "carpet beetles are evil!"
#     *   Keyword: "evil" (strongly negative connotation).
#     *   Punctuation: "!" (emphasizes the emotion).
#
#     *   The sentiment is clearly negative.
# [End thinking]
#
# negative
#
# ---
#
# ### Name recognition
#
# With the system prompt: You pick out names from text. Do not provide disclaimers about who you are and what your role is.
#
# **Zero-shot**
#
# "Your task is to pick out all of the names that appear in the given text:... and that's why the death of Harambe was the event horizon for the AI wars of 2030."
#
# [Start thinking]
#
# *   Task: Pick out names from the text.
#     *   Constraint: No disclaimers about role/identity.
#     *   Input text: "... and that's why the death of Harambe was the event horizon for the AI wars of 2030."
#
#     *   "Harambe" (Proper name of a gorilla).
#     *   "AI" (Acronym for Artificial Intelligence - generally not considered a "name" in the sense of a person/entity, but a concept).
#     *   "2030" (Number/Year).
#
#     *   Harambe.
# [End thinking]
#
# Harambe
#
#
# **One-shot**
#
# "Your task is to pick out all of the names that appear in the given text. Here is an example:... and that's why the death of Harambe was the event horizon for the AI wars of 2030.\names:Harambe\n\nNow your turn, here's the text:\nuser1:Morbius and Madame Web had a higher rotten tomatoes rating. Let that sink in.\n user2:What does the sink want now?"
#
# [Start thinking]
#
# *   Task: Pick out names from the provided text.
#     *   Constraint: Do not provide disclaimers.
#     *   Input text: "user1:Morbius and Madame Web had a higher rotten tomatoes rating. Let that sink in.\n user2:What does the sink want now?"
#
#     *   "user1" (username/identifier, usually not a proper name in this context, but "Morbius" and "Madame Web" are character names).
#     *   "Morbius" (Proper noun/Character name).
#     *   "Madame Web" (Proper noun/Character name).
#     *   "rotten tomatoes" (Brand/Website name, usually treated as a name of an entity).
#     *   "user2" (username/identifier).
#
#     *   Morbius
#     *   Madame Web
#
#     *   Should "Rotten Tomatoes" be included? It's a proper noun.
#     *   Should "user1" and "user2" be included? Usually, those are labels.
#     *   The example used "Harambe" (a specific named entity).
#
#     *   Names: Morbius, Madame Web
# [End thinking]
#
# names:Morbius, Madame Web
#
#
# **Two-shot**
# "Your task is to pick out all of the names that appear in the given text. Here is the first example:... and that's why the death of Harambe was the event horizon for the AI wars of 2030.\names:Harambe\nHere is the second example\nuser1:Morbius and Madame Web had a higher rotten tomatoes rating. Let that sink in.\n user2:What does the sink want now?\nnames:Morbius, Madame Web\n\nNow your turn, here's the text: Agenda piece. the funniest agenda I ever saw was the Dragon brought the rain so he could hide that he was sweating against East Blue Smoker."
#
#
# [Start thinking]
#
# *   Task: Pick out names from text.
#     *   Constraint: No disclaimers.
#     *   Input text: "Agenda piece. the funniest agenda I ever saw was the Dragon brought the rain so he could hide that he was sweating against East Blue Smoker."
#
#     *   "Agenda piece." -> No names.
#     *   "the funniest agenda I ever saw was the Dragon brought the rain so he could hide that he was sweating against East Blue Smoker."
#     *   Potential names: "Dragon", "East Blue Smoker" (or "Smoker").
#     *   Context: This is a reference to One Piece. "Dragon" (Monkey D. Dragon) and "Smoker" are characters. "East Blue" is a location.
#
#     *   Name 1: Dragon
#     *   Name 2: Smoker
#
#     *   Follow the pattern: `names:Name1, Name2`
# [End thinking]
#
# names:Dragon, Smoker
#
# ---
#
# ### Addition
#
# With the system prompt: You do arithmetic addition and provide the sum as the answer. Do not provide disclaimers about who you are and what your role is.
#
# **Zero-shot**
#
# Your task is to add two given digits together, and provide their sum as your answer.\nHere are the digits: 67 + 69
#
# [Start thinking]
#
# *   Input: Two digits (actually numbers) to add: 67 + 69.
#     *   Task: Provide the sum as the answer.
#     *   Constraint: No disclaimers about identity or role.
#
#     *   67 + 69
#     *   60 + 60 = 120
#     *   7 + 9 = 16
#     *   120 + 16 = 136
#
#     *   The sum is 136.
# [End thinking]
#
# 136
#
#
# **One-shot**
#
# Your task is to add two given digits together, and provide their sum as your answer.\nHere is an example: 67 + 69 = 136.\n\nYour turn to try: 182+1984 =
#
# [Start thinking]
#
# *   Operation: Addition.
#     *   Numbers: 182 and 1984.
#     *   Constraint: Provide only the sum. No disclaimers.
#
#     *   182 + 1984 = ?
#     *   1000 + (900 + 100) + (80 + 80) + (4 + 2)
#     *   1000 + 1000 + 160 + 6
#     *   2000 + 166 = 2166
#
#     *   182 + 1984
#     *   2 + 4 = 6
#     *   80 + 80 = 160
#     *   100 + 900 = 1000
#     *   1000 = 1000
#     *   Total: 1000 + 1000 + 160 + 6 = 2166.
#
#     *   2166.
# [End thinking]
#
# 2166
#
#
# **Two-shot**
# Your task is to add two given digits together, and provide their sum as your answer.\nHere is an example: 67 + 69 = 136.\nHere is another example: 182+1984 = 2166\n\nYour turn to try: 82567 + 1049623
#
# [Start thinking]
#
# *   Input: 82,567 + 1,049,623
#     *   Task: Addition
#     *   Constraint: Provide only the sum, no disclaimers.
#
#     *   1,049,623
#     *   + 82,567
#     *   -----------
#     *   (3+7) = 10 (Write 0, carry 1)
#     *   (2+6+1) = 9
#     *   (6+5) = 11 (Write 1, carry 1)
#     *   (9+2+1) = 12 (Write 2, carry 1)
#     *   (4+8+1) = 13 (Write 3, carry 1)
#     *   (0+1) = 1
#     *   (1+0) = 1
#
#     *   1,132,190
#
#     *   1,049,623 + 80,000 = 1,129,623
#     *   1,129,623 + 2,567 = 1,132,190
#     *   Calculation:
#         1,049,623
#         + 82,567
#         ----------
#         1,132,190
#
#     *   Result: 1132190
# [End thinking]
#
# 1132190

# %% [markdown]
# # Results
#
# For all of the tasks Gemma 4 31b thinking succeeded without any issues, and correctly answered all the first time around for zero-, one-, and two-shot prompts.
#
# I also tested out Gemma 2 9b non-thinking model, and it also succeeded perfectly without any issues.
#
# For both, I even tried running the prompts multiple times, but they made no mistakes.
#
#
# Most of these results aren't surprising. The tasks given were relatively simple, and these are large enough models to handle them. Though, I was somewhat expecting them to fail (at least the 9b model) at the arithmetic task, as they're not usually super great at that. Especially older models like Gemma 2.
#
# All of this doesn't mean LLMs can't make mistakes, they make them plenty of times. But, generally the tasks need to be more complex, long running (enought to eat up the context window), lacking in context (information), or otherwise brand new to the LLM for issues to start appearing.

# %% [markdown]
# **Submit this exercise by submitting your code and your answers to the above questions as comments on the MOOC platform. You can return this Jupyter notebook (.ipynb) or .py, .R, etc depending on your programming preferences.**
